# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
kashti = sns.load_dataset('titanic')

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti['survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
sns.countplot(x='survived', hue='sex',data=kashti)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.scatterplot( x='age' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot( x='sex' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot( x='sex' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot( x='sex' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot( x='age' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# Create the boxplot
ax = sns.boxplot(x='sex', y='fare', hue='pclass', data=kashti)

# Change x and y axis labels
ax.set(xlabel='Gender', ylabel='Fare Amount ($)')

# Optionally, add a title
ax.set_title('Boxplot of Fare by Gender and Passenger Class')

# Show the plot
plt.show()

# %%
sns.boxplot( x='age' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.scatter(x='age',data=kashti,y='fare')

# %%
sns.pairplot(kashti)

# %%
kashti.hist(bins=10, figsize=(9,7),grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
import seaborn as sns
import pandas as pd

# Assuming `kashti` is a DataFrame
kashti['pclass_who'] = kashti['pclass'].astype(str) + '_' + kashti['who']

# Create the boxplot
sns.boxplot(x='sex', y='fare', hue='pclass_who', data=kashti)
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# Grid Plot
g = sns.FacetGrid( kashti , col='pclass' , hue='survived' , margin_titles=True , palette={ 1:'seagreen' , 0:'grey'} )
g = g.map( plt.scatter , 'fare' , 'age' , edgecolor='w' , alpha=0.7 , s=50 ).add_legend();

# %%
# Grid Plot
g = sns.FacetGrid( kashti , col='sex' , hue='survived' , margin_titles=True , palette={ 1:'seagreen' , 0:'grey'} )
g = g.map( plt.scatter , 'fare' , 'age' , edgecolor='w' , alpha=0.7 , s=50 ).add_legend();

# %%
# Grid Plot
g = sns.FacetGrid( kashti , col='who' , hue='survived' , margin_titles=True , palette={ 1:'seagreen' , 0:'grey'} )
g = g.map( plt.scatter , 'fare' , 'age' , edgecolor='w' , alpha=0.7 , s=50 ).add_legend();

# %%
sns.stripplot( x='sex' , y='fare' , hue='pclass' , data=kashti )
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# Compute correlation matrix for numeric columns
corr = kashti.select_dtypes(include=['number']).corr()

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap with better formatting
sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)

plt.title("Correlation Heatmap of Titanic Dataset", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
